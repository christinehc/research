# %% [markdown]
# ## Import functions

# %%
from xpsfit import full_xps_fit, one_component_xps_fit, two_component_xps_fit

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20180601/BP control - survey.xlsx', sheet='Sheet7', skip=7, name="control_P2p")

# %%
two_component_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20180703/CHC-083 - all.xlsx', sheet='Sheet7', name='BAN3_photolysis', skipshift=True, residuals=True)
# Out:
# Data for BAN3_photolysis
# Proportions are {'a': 0.06436880578636713, 'b': 0.5667730804195072, 'c': 0.36885811379412564}
# Distances are {'ab_dist': 3.307592387808171, 'ac_dist': 4.043494433127648}

# %%
two_component_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/XPS time-resolved photolysis/20190328/photolysis_control.xlsx', sheet='Sheet5', name='BP-control_photolysis_resid', residuals=True)
# Out:
# Data for BP-control_photolysis_resid
# Proportions are {'a': 0.9741089113012207, 'b': 0.025891088698779315}
# Distances are {'ab_dist': 3.3232462526740107}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/XPS 20190501/DT-2-30_all.xlsx', sheet='Sheet5', name='DT_2-30')
# Out:
# Data for DT_2-30
# Proportions are {'a': 0.8625690701622267, 'b': 0.05810884361296475, 'c': 0.07932208622480848}
# Distances are {'ab_dist': 3.0486155980815397, 'ac_dist': 3.9348637421911405}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/XPS 20190501/DT-2-30_all.xlsx', sheet='Sheet5', name='DT_2-30_resid', residuals=True)
# Out:
# Data for DT_2-30_resid
# Proportions are {'a': 0.8625690701622267, 'b': 0.05810884361296475, 'c': 0.07932208622480848}
# Distances are {'ab_dist': 3.0486155980815397, 'ac_dist': 3.9348637421911405}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20180601/BP 2d ambient - survey.xlsx', sheet='Sheet7', name='BP_ambient_2-5d')
# Out:
# Data for BP_ambient_2-5d
# Proportions are {'a': 0.8442408656441786, 'b': 0.07991932172709754, 'c': 0.07583981262872382}
# Distances are {'ab_dist': 3.0670746587976794, 'ac_dist': 4.238473788526846}

# %% [markdown]
# ## Generating Plots

# %% [markdown]
# Plots can be easily generated using the functions defined in `xps_fit.py`. The functions handle importing the data, fitting the components, printing outputs in a nicer format, drawing a graph, and potentially also saving the data.

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20190402/BP-Ts_KW-0d_all.xlsx', sheet='Sheet5', name='KLW0', residuals=True)
# Out:
# Data for KLW0
# Proportions are {'a': 0.9298470444415009, 'b': 0.031033500732940516, 'c': 0.03911945482555851}
# Distances are {'ab_dist': 2.754797700503616, 'ac_dist': 4.003326360183792}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20190402/BP-Ts_KW-1d_all.xlsx', sheet='Sheet5', name='KLW1', residuals=True)
# Out:
# Data for KLW1
# Proportions are {'a': 0.8055405067188166, 'b': 0.11752968692818097, 'c': 0.07692980635300248}
# Distances are {'ab_dist': 3.277229912270684, 'ac_dist': 4.461129089097227}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20190402/BP-Ts_KW-2d_all.xlsx', sheet='Sheet5', name='KLW2', residuals=True)
# Out:
# Data for KLW2
# Proportions are {'a': 0.873261782074388, 'b': 0.06494125516597078, 'c': 0.061796962759641125}
# Distances are {'ab_dist': 0.876426558955842, 'ac_dist': 3.6519690780559415}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/XPS 20190429/KW-3d_all.xlsx', sheet='Sheet5', name='KLW3', residuals=True)
# Out:
# Data for KLW3
# Proportions are {'a': 0.8527884270552767, 'b': 0.102980496665819, 'c': 0.04423107627890426}
# Distances are {'ab_dist': 1.171613313482112, 'ac_dist': 2.982626064381975}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/XPS 20190429/KW-4d_all.xlsx', sheet='Sheet5', name='KLW4', residuals=True)
# Out:
# Data for KLW4
# Proportions are {'a': 0.8192343078824479, 'b': 0.12421258460704031, 'c': 0.05655310751051185}
# Distances are {'ab_dist': 1.0092244505123347, 'ac_dist': 2.9251806493916774}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20190410/KW-5d_spectra.xlsx', sheet='Sheet5', name='KLW5', residuals=True)
# Out:
# Data for KLW5
# Proportions are {'a': 0.40746216963508586, 'b': 0.2050721344759337, 'c': 0.3874656958889804}
# Distances are {'ab_dist': 2.718329475745776, 'ac_dist': 4.0193515683081955}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20190402/CHC-154_all.xlsx', sheet='Sheet5', name='CHC-154')
# Out:
# Data for CHC-154
# Proportions are {'a': 0.5016819720529547, 'b': 0.2183322524606075, 'c': 0.2799857754864377}
# Distances are {'ab_dist': 3.439605732742109, 'ac_dist': 4.487506227532577}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20190402/CHC-154_control_all.xlsx', sheet='Sheet5', name='BP-control_thermolyzed', residuals=True)
# Out:
# Data for BP-control_thermolyzed
# Proportions are {'a': 0.9050239074249083, 'b': 0.041350622114198626, 'c': 0.05362547046089306}
# Distances are {'ab_dist': 2.854783162513627, 'ac_dist': 3.7837199898575875}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20190402/CHC-154_all.xlsx', sheet='Sheet5', name='BP thermolyzed with MeBzN3', residuals=True)
# Out:
# Data for BP thermolyzed with MeBzN3
# Proportions are {'a': 0.5016819720529547, 'b': 0.2183322524606075, 'c': 0.2799857754864377}
# Distances are {'ab_dist': 3.439605732742109, 'ac_dist': 4.487506227532577}

# %%
one_component_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/XPS time-resolved photolysis/real_ctrl.xlsx', sheet='Sheet5', name='BP_ctrl_no-resid')#, residuals=True)
# Out:
# Data for BP_ctrl_no-resid

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/XPS time-resolved photolysis/real_2h.xlsx', sheet='Sheet5', name='Time-Resolved_Ts_2h')
# Out:
# Data for Time-Resolved_Ts_2h
# Proportions are {'a': 0.9269592845130261, 'b': 0.041623587104066447, 'c': 0.03141712838290735}
# Distances are {'ab_dist': 2.652766078900072, 'ac_dist': 4.1942232623808025}

# %%
two_component_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/XPS time-resolved photolysis/20190328/4h.xlsx', sheet='Sheet5', name='Time-Resolved_Ts_4h')
# Out:
# Data for Time-Resolved_Ts_4h
# Proportions are {'a': 0.9791909144431881, 'b': 0.020809085556811904}
# Distances are {'ab_dist': 3.3367506527371518}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20180703/CHC-086 - all.xlsx', sheet='Sheet11', name="Slide-10_Ts")
# Out:
# Data for Slide-10_Ts
# Proportions are {'a': 0.8936905289102882, 'b': 0.04749916294136933, 'c': 0.058810308148342524}
# Distances are {'ab_dist': 3.154083148940032, 'ac_dist': 4.079627129083974}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20180703/CHC-086 - all.xlsx', sheet='Sheet11', name="BP-NTs_resid", residuals=True)
# Out:
# Data for BP-NTs_resid
# Proportions are {'a': 0.8936905289102882, 'b': 0.04749916294136933, 'c': 0.058810308148342524}
# Distances are {'ab_dist': 3.154083148940032, 'ac_dist': 4.079627129083974}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/CHC-125 - spectra.xlsx', sheet='Sheet8', name="BP-NBzMe", residuals=True)
# Out:
# Data for BP-NBzMe
# Proportions are {'a': 0.8635197257060105, 'b': 0.07402892053930578, 'c': 0.062451353754683754}
# Distances are {'ab_dist': 2.792878937021328, 'ac_dist': 4.210341398822862}

# %%
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20180703/CHC-081 - all.xlsx', sheet='Sheet11', name="BP-NAd", residuals=True)
# Out:
# Data for BP-NAd
# Proportions are {'a': 0.923171295877784, 'b': 0.03495086764076561, 'c': 0.04187783648145031}
# Distances are {'ab_dist': 2.7897457617351904, 'ac_dist': 3.8527610227202445}

# %%
# Ts mild
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20180523/CHC-049.xlsx', sheet='Sheet9', skip=8)
# Out:
# Data for False
# Proportions are {'a': 0.9604500860681864, 'b': 0.021331191416398942, 'c': 0.018218722515414683}
# Distances are {'ab_dist': 3.554483521323249, 'ac_dist': 4.319387845021538}

# %%
# BA mild
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20180523/CHC-067.xlsx', sheet='Sheet9', skip=8, name='BP-NBA_mild', residuals=True)
# Out:
# Data for BP-NBA_mild
# Proportions are {'a': 0.9314047565576966, 'b': 0.043184917764005945, 'c': 0.025410325678297405}
# Distances are {'ab_dist': 3.3356139041708843, 'ac_dist': 4.292560988513287}

# %%
# Ad mild
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20180523/CHC-068.xlsx', sheet='Sheet9', skip=8, name='BP-NAd_mild', residuals=True)
# Out:
# Data for BP-NAd_mild
# Proportions are {'a': 0.942185569040729, 'b': 0.02375238176429358, 'c': 0.034062049194977316}
# Distances are {'ab_dist': 2.899875824116805, 'ac_dist': 4.043594674214432}

# %%
# CHC-156

full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20190410/CHC-156_spectra.xlsx', sheet='Sheet5', residuals=True, name='BP-NTs_1h+1h_intermediate_addition')
# Out:
# Data for BP-NTs_1h+1h_intermediate_addition
# Proportions are {'a': 0.8838143407896024, 'b': 0.08343974569605586, 'c': 0.032745913514341606}
# Distances are {'ab_dist': 2.2593364880295326, 'ac_dist': 3.805832893121135}

# %%
# CHC-157
full_xps_fit('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20190410/CHC-157_spectra.xlsx', sheet='Sheet5', b=132.25, residuals=True, name='BP-NTs_quartz_flask')
# Out:
# Data for BP-NTs_quartz_flask
# Proportions are {'a': 0.8773818331616535, 'b': 0.045052380649943165, 'c': 0.0775657861884033}
# Distances are {'ab_dist': 2.252911094069617, 'ac_dist': 4.169412015420818}

# %% [markdown]
# ### fit data using LMFIT

# %% [markdown]
# Fit the data using a list of energies for oxidation state components and a list of their relative intensities.
#
# Start points:
#
# centralenergies = (120.0, 123.0, 124.0)
#
# relativeintensities = (1, 0.1, 0.25)

# %%
data = read_xps_data_from_excel('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20190410/CHC-156_spectra.xlsx', sheet_name='Sheet5')
fitoutput, model, parameters = xps_fit(data, [120.0, 123.0, 124.0], [1, 0.1, 0.25])

# %%
fitoutput.params['b1_center'].set(122, vary=False)

# %%
fitoutput.params['b1_center']
# Out:
# <Parameter 'b1_center', value=122 (fixed), bounds=[-inf:inf]>

# %% [markdown]
# ### Plots

# %%
gs = gridspec.GridSpec(2, 4, height_ratios=[1,2.5], hspace=0)

plt.figure(figsize=(20,5))

axr1 = plt.subplot(gs[0, 0])
axr2 = plt.subplot(gs[1, 0])
axr3 = plt.subplot(gs[0, 1])
axr4 = plt.subplot(gs[1, 1])
axr5 = plt.subplot(gs[0, 2])
axr6 = plt.subplot(gs[1, 2])
axr7 = plt.subplot(gs[0, 3])
axr8 = plt.subplot(gs[1, 3])

axr = np.array([axr1, axr2, axr3, axr4, axr5, axr6, axr7, axr8])

nambfitoutput.plot_residuals(ax=axr1)
plot_xps_fit(nambfitoutput, ax=axr2)
nfitoutput.plot_residuals(ax=axr3)
plot_xps_fit(nfitoutput, ax=axr4)
nmeba_fitoutput.plot_residuals(ax=axr5)
plot_xps_fit(nmeba_fitoutput, ax=axr6)
nad_fitoutput.plot_residuals(ax=axr7)
plot_xps_fit(nad_fitoutput, ax=axr8)

plt.rcParams['xtick.labelsize']=16
plt.rcParams['ytick.labelsize']=16
plt.rcParams['axes.labelsize']=20

for axis in axr.flat:
    axis.invert_xaxis()
    axis.set(xlabel='Binding Energy (eV)', ylabel ='Residuals', xlim=(137,127), title=None)
    axis.minorticks_on()
    axis.label_outer() #only label the left plot's y-axis
    if axis.get_legend():
        axis.get_legend().remove()
        axis.set(ylim=(-350,350))
    axis.get_yaxis().set_visible(False)

# r'TsN$_{3}$ Residuals'

plt.show()

# %% [markdown]
# Then we can calculate the relative proportions of the components.  The area of each peak is divided by the sum of all of the components:

# %%
print(fitoutput.fit_report())
# Out:
# [[Model]]
#     (((Model(voigt, prefix='a1_') + Model(voigt, prefix='a2_')) + (Model(voigt, prefix='b1_') + Model(voigt, prefix='b2_'))) + (Model(voigt, prefix='c1_') + Model(voigt, prefix='c2_')))
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 106
#     # data points      = 162
#     # variables        = 6
#     chi-square         = 641947.313
#     reduced chi-square = 4115.04688
#     Akaike info crit   = 1354.11576
#     Bayesian info crit = 1372.64134
# [[Variables]]
#     a1_sigma:      0.35 (fixed)
#     a1_center:     120.137907 +/- 0.00204091 (0.00%) (init = 120)
#     a1_amplitude:  7226.82653 +/- 17.3610323 (0.24%) (init = 6533)
#     a2_sigma:      0.35000000 +/- 0.00000000 (0.00%) == 'a1_sigma'
#     a2_center:     120.977907 +/- 0.00204091 (0.00%) == 'a1_center--0.84'
#     a2_amplitude:  3613.41326 +/- 8.68051615 (0.24%) == 'a1_amplitude*0.5'
#     a1_gamma:      0.15 (fixed)
# ...

# %%
print(ambfitoutput.fit_report())
# Out:
# [[Model]]
#     (((Model(voigt, prefix='a1_') + Model(voigt, prefix='a2_')) + (Model(voigt, prefix='b1_') + Model(voigt, prefix='b2_'))) + (Model(voigt, prefix='c1_') + Model(voigt, prefix='c2_')))
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 120
#     # data points      = 181
#     # variables        = 6
#     chi-square         = 435111.331
#     reduced chi-square = 2486.35046
#     Akaike info crit   = 1421.05969
#     Bayesian info crit = 1440.25067
# [[Variables]]
#     a1_sigma:      0.35 (fixed)
#     a1_center:     119.971153 +/- 0.00275632 (0.00%) (init = 120)
#     a1_amplitude:  4159.92752 +/- 13.4960584 (0.32%) (init = 3700)
#     a2_sigma:      0.35000000 +/- 0.00000000 (0.00%) == 'a1_sigma'
#     a2_center:     120.811153 +/- 0.00275632 (0.00%) == 'a1_center--0.84'
#     a2_amplitude:  2079.96376 +/- 6.74802921 (0.32%) == 'a1_amplitude*0.5'
#     a1_gamma:      0.15 (fixed)
# ...

# %% [markdown]
# ### To customize fitting constraints

# %% [markdown]
# Take the model and parameters from the previous output, then adjust individual parameters as necessary in the fit output to then perform a new fit:

# %%
plength = len(ts30m1_fitoutput.params) / 12
range(int(plength))[1]
# Out:
# 1

# %%
fitoutput.params['b1_amplitude'].set(value=500)

# %%
fitoutput.params['a1_center'].set(value=120.5, vary=False)

# %%
fitoutput.params.pretty_print()
# Out:
# Name             Value      Min      Max   Stderr     Vary     Expr Brute_Step
# a1_amplitude      7154     -inf      inf    26.75     True     None     None
# a1_center        120.5     -inf      inf 0.003149    False     None     None
# a1_fwhm         0.9963     -inf      inf        0    False 1.0692*a1_gamma+sqrt(0.8664*a1_gamma**2+5.545083*a1_sigma**2)     None
# a1_gamma          0.15     -inf      inf        0    False     None     None
# a1_height         5973     -inf      inf    22.33    False (a1_amplitude/(a1_sigma*sqrt(2*pi)))*wofz((1j*a1_gamma)/(a1_sigma*sqrt(2))).real     None
# a1_sigma          0.35        0      inf        0    False     None     None
# a2_amplitude      3577     -inf      inf    13.37    False a1_amplitude*0.5     None
# a2_center        121.3     -inf      inf 0.003149    False a1_center--0.8     None
# a2_fwhm         0.9963     -inf      inf        0    False 1.0692*a2_gamma+sqrt(0.8664*a2_gamma**2+5.545083*a2_sigma**2)     None
# ...

# %% [markdown]
# Then re-run the fit as follows:

# %%
fitoutput.fit()

# %% [markdown]
# In this case the fit got worse since I contrained one of the parameters to a non-physical value.

# %%
plot_xps_fit(fitoutput)

# %% [markdown]
# ## Initialization

# %%
from lmfit import models
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Customized code

# %%
from operator import add
from functools import reduce

def read_xps_data_from_excel(file, sheet_name, skiprows=7):
    raw = pd.read_excel(file, sheet_name=sheet_name, skiprows=skiprows)

    try:
        new = pd.DataFrame()
        new['BindingEnergy'] = raw['B. E.']
        new['Counts'] = raw['Counts']
        new['FitRegion_BindingEnergy'] = raw['PkGrp1_BE']
        new['FitBackground'] = raw['PkGrp1_Count']
        new['FitEnvelope'] = raw['PkFitEnv1']
        
        #Search for variable number of peaks
        peaki = 1
        while True:
            try:
                new['Peak{}'.format(peaki)] = raw['Pk0{}'.format(peaki)]
                peaki += 1
            except KeyError:
                break
    except KeyError:
        print('File does not match peak finding pattern Pk01, Pk02, ..., returning raw columns')
        new = pd.DataFrame()
        new['BindingEnergy'] = raw['B. E.']
        new['Counts'] = raw['Counts']
        for k in raw.keys():
            if k != 'B. E.' and k != 'Count':
                new[k] = raw[k]
    return new

def plot_xps_data_matplotlib(xpsdataframe):
    plt.plot(xpsdataframe['BindingEnergy'], xpsdataframe['Counts'], label='AllData')
    
    x = xpsdataframe['FitRegion_BindingEnergy']
    for k in xpsdataframe.keys()[3:]:
        plt.plot(x, xpsdataframe[k], label=k)
    
    plt.xlabel('Binding Energy (eV)')
    plt.gca().invert_xaxis()
    plt.legend()
    plt.show()

def take_energy_range(energies, data, erange):
    indices = (energies >= erange[0]) & (energies <= erange[1])
    return np.array([energies[indices], data[indices]])

def get_background_subtracted_data(xpsdataframe):
    croppednans = xpsdataframe['FitRegion_BindingEnergy'][pd.notna(xpsdataframe['FitRegion_BindingEnergy'])]
    upper = croppednans.iloc[0]
    lower = croppednans.iloc[-1]
    energies, data = take_energy_range(xpsdataframe['BindingEnergy'], xpsdataframe['Counts'], [lower, upper])
    assert (energies - croppednans < 1e-10).all(), 'Energy grid of BindingEnergy and FitRegion_BindingEnergy did not match'
    new = {}
    new['BindingEnergy'] = energies
    new['Counts'] = data - xpsdataframe['FitBackground'][pd.notna(xpsdataframe['FitBackground'])]
    return pd.DataFrame(new)

def doublet_peakshape_model(mainpeakpos=120, gamma=0.15, sigma=0.35, splitting=-0.84, ratio=2, prefix='a'):
    """Makes lmfit model of doublet shape.
    
    Model is composed of two voigts with fixed Lorentzian
     and Gaussian widths and fixed splitting and peak ratios.

    Args:
        mainpeakpos: Energy (eV) position of main peak.
        gamma: Lorentzian width (in voigt model).
        sigma: Gaussian width (in voigt model).
        splitting: Energy gap (eV) between the two components
        ratio: Ratio of peak heights a1/a2

    Returns:
        lmfit model, lmfit pars

    Raises:
        Nothing.
    """
    prefix1 = prefix + '1_'
    prefix2 = prefix + '2_'
    mod = models.VoigtModel(prefix=prefix1)+models.VoigtModel(prefix=prefix2)
    pars = mod.make_params()
    parsdict = dict([[prefix2+'amplitude',{'expr': prefix1+'amplitude*'+str(1/ratio), 'value': 1/ratio, 'vary': False}],
                     [prefix2+'gamma', {'expr': prefix1+'gamma', 'value': gamma, 'vary': False}],
                     [prefix2+'center', {'expr': prefix1+'center-'+str(splitting), 'value': mainpeakpos-splitting, 'vary': False}],
                     [prefix1+'sigma', {'expr': '', 'value': sigma, 'vary': False}],
                     [prefix1+'gamma', {'expr': '', 'value': gamma, 'vary': False}],
                     [prefix1+'center', {'expr': '', 'value': mainpeakpos, 'vary': True}],
                     [prefix2+'sigma', {'expr': prefix1+'sigma', 'value': sigma, 'vary': False}]])
    for k,v in parsdict.items():
        pars[k].set(vary=v['vary'],expr=v['expr'])
    for k,v in parsdict.items():
        pars[k].value=v['value']
    return mod, pars

def multiple_doublet_model(centralenergies, relativeintensities):
    assert len(centralenergies) == len(relativeintensities), 'Intensities and energies must have same length.'
    models = []
    parslist = []
    alphabet = 'abcdefghijklmnopqrstuvwxyz'
    for i in range(len(centralenergies)):
        mod, pars = doublet_peakshape_model(centralenergies[i], prefix=alphabet[i])
        pars[alphabet[i]+'1_amplitude'].set(value=relativeintensities[i])
        models.append(mod)
        parslist.append(pars)
    totalmodel = reduce(add, models)
    totalpars = reduce(add, parslist)
    return totalmodel, totalpars

def xps_fit(xpsdataframe, centralenergies, relativeintensities):
    bgsub = get_background_subtracted_data(xpsdataframe)
    energies = bgsub['BindingEnergy']
    data = bgsub['Counts']
    mod, pars = multiple_doublet_model(centralenergies, relativeintensities)
    for k in pars.keys():
        if '1_amplitude' in k:
            pars[k].set(value=data.max() * pars[k].value)
    fit = mod.fit(data, params=pars, x=energies)
    return fit, mod, pars

def plot_xps_fit(fit, showallcomponents=False):
    x = fit.userkws['x']
    plt.plot(x, fit.data, label='Data')
    plt.plot(x, fit.eval(x=x), label='Fit')
    components = fit.eval_components(x=x)
    
    uniqueprefixes = sorted(list(set([s[:-2] for s in components.keys()])))
    for p in uniqueprefixes:
        plt.plot(x, components[p+'1_'] + components[p+'2_'], label=p)
        
    if showallcomponents:
        for k, v in components.items():
            plt.plot(x, v, 'k--', alpha=0.5)
        
    plt.legend()
    plt.xlabel('Binding Energy (eV)')
    plt.gca().invert_xaxis()
    plt.ylabel('Intensity (a.u.)')
    plt.show()

def calculate_component_percentages(fit):
    components = fit.eval_components()
    uniqueprefixes = sorted(list(set([s[:-2] for s in components.keys()])))
    intensities = {}
    for p in uniqueprefixes:
        intensities[p] = np.sum(components[p+'1_'] + components[p+'2_'])
    total = np.sum(list(intensities.values()))
    for k, v in intensities.items():
        intensities[k] = v / total
    return intensities

def calculate_p_deltas(fit):
    pdict = {}
    pdict['ab_dist'] = abs(fit.params['a1_center'].value
                           - fit.params['b1_center'].value)
    pdict['ac_dist'] = abs(fit.params['a1_center'].value
                           - fit.params['c1_center'].value)
    return pdict
