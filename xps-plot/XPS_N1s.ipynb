# %% [markdown]
# # Initialization

# %%
from xpsfit import read_xps_data_from_excel, plot_xps_data_matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd
import numpy as np

# %matplotlib inline

# %% [markdown]
# # Creating Plots

# %% [markdown]
# ### BP Control

# %%
BP_ctrl_N1s = read_xps_data_from_excel('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/XPS time-resolved photolysis/real_ctrl.xlsx',
                                       sheet_name="Sheet3",
                                       be_shift=10.2)
# Peaks: 399.6 (87.6%), 400.9 (12.4%)

# %%
plot_xps_data_matplotlib(BP_ctrl_N1s, name="BP_ctrl")

# %% [markdown]
# ### BP Photolysis Control

# %%
BP_hv_ctrl = read_xps_data_from_excel('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/XPS time-resolved photolysis/20190328/photolysis_control.xlsx',
                                       sheet_name="Sheet3",
                                       be_shift=9.82)
# Peaks: 399.7 (57.5%) 402.0 (42.5%)

# %%
plot_xps_data_matplotlib(BP_hv_ctrl, name="BP_hv_ctrl")

# %% [markdown]
# ### BP-NTs

# %%
BP_NTs = read_xps_data_from_excel('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20180703/CHC-086 - all.xlsx',
                                       sheet_name="Sheet9",
                                       be_shift=9.46)
# Peak: 399.8 (100%)

# %%
plot_xps_data_matplotlib(BP_NTs, name="BP_NTs")

# %% [markdown]
# ### BP-NMeBz

# %%
BP_NMeBz = read_xps_data_from_excel('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/CHC-125 - spectra.xlsx',
                                       sheet_name="Sheet6",
                                       be_shift=9.87)
# Peaks: 399.6 (89.7%), 401.6 (10.3%)

# %%
plot_xps_data_matplotlib(BP_NMeBz, name="BP_NMeBz")

# %% [markdown]
# ### BP-NAd

# %%
BP_NAd = read_xps_data_from_excel('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20180703/CHC-081 - all.xlsx',
                                       sheet_name="Sheet9",
                                       be_shift=9.41)
# Peak: 399.549 (100%)

# %%
plot_xps_data_matplotlib(BP_NAd, name="BP_NAd")

# %% [markdown]
# ### BP-NBA

# %%
BP_BA_hv = read_xps_data_from_excel('/mnt/c/Users/Christine/Documents/School/Work/Data/XPS/20180703/CHC-083 - all.xlsx',
                                    sheet_name="Sheet9",
                                    be_shift=9.1)
# Peak: 399.9 (100%)

# %%
plot_xps_data_matplotlib(BP_BA_hv, name="BP_BA_hv")
